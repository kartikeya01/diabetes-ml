# %%
# We import the libraries needed to read the dataset
import os
import pandas as pd
import numpy as np

# %%
DATASET_PATH = 'NHANES/2013-2014/'

# %%
data_path = os.path.join(DATASET_PATH, 'BMX_H.csv')
dataset = pd.read_csv(data_path)

# %%
dataset.shape
# Out:
# (9813, 26)

# %%
dataset.head()
# Out:
#     SEQN  BMDSTATS  BMXWT  BMIWT  BMXRECUM  BMIRECUM  BMXHEAD  BMIHEAD  BMXHT  \
# 0  73557         1   78.3    NaN       NaN       NaN      NaN      NaN  171.3
# 1  73558         1   89.5    NaN       NaN       NaN      NaN      NaN  176.8
# 2  73559         1   88.9    NaN       NaN       NaN      NaN      NaN  175.3
# 3  73560         1   32.2    NaN       NaN       NaN      NaN      NaN  137.3
# 4  73561         3   52.0    NaN       NaN       NaN      NaN      NaN  162.4
#
#    BMIHT  ...  BMXARMC  BMIARMC  BMXWAIST  BMIWAIST  BMXSAD1  BMXSAD2  \
# 0    NaN  ...     35.3      NaN     100.0       NaN     20.5     20.6
# 1    NaN  ...     34.7      NaN     107.6       NaN     24.2     24.5
# 2    NaN  ...     33.5      NaN     109.2       NaN     25.8     25.4
# 3    NaN  ...     21.0      NaN      61.0       NaN     14.8     15.0
# 4    NaN  ...     25.2      NaN       NaN       1.0      NaN      NaN
#
#    BMXSAD3  BMXSAD4  BMDAVSAD  BMDSADCM
# 0      NaN      NaN      20.6       NaN
# 1      NaN      NaN      24.4       NaN
# 2      NaN      NaN      25.6       NaN
# 3      NaN      NaN      14.9       NaN
# 4      NaN      NaN       NaN       1.0
#
# [5 rows x 26 columns]

# %%
corr = dataset.corr()
corr
# Out:
#               SEQN  BMDSTATS     BMXWT     BMIWT  BMXRECUM  BMIRECUM  \
# SEQN      1.000000  0.015038  0.000114 -0.121727 -0.042249       NaN
# BMDSTATS  0.015038  1.000000  0.055510 -0.343110  0.190032       NaN
# BMXWT     0.000114  0.055510  1.000000  0.116458  0.942248       NaN
# BMIWT    -0.121727 -0.343110  0.116458  1.000000  0.000930       NaN
# BMXRECUM -0.042249  0.190032  0.942248  0.000930  1.000000       NaN
# BMIRECUM       NaN       NaN       NaN       NaN       NaN       NaN
# BMXHEAD  -0.010439 -0.062196  0.872206       NaN  0.877795       NaN
# BMIHEAD        NaN       NaN       NaN       NaN       NaN       NaN
# BMXHT     0.014407 -0.038417  0.786989  0.010077  0.990304       NaN
# BMIHT    -0.012143 -0.503746  0.507097  0.480347       NaN       NaN
# BMXBMI   -0.011607  0.108165  0.915415  0.099862  0.035132       NaN
# BMDBMIC  -0.002133  0.007455  0.479736  0.039827  0.140008       NaN
# BMXLEG    0.003024 -0.047323  0.460134 -0.040359       NaN       NaN
# BMILEG         NaN       NaN       NaN       NaN       NaN       NaN
# BMXARML   0.017392  0.028300  0.854641 -0.053570  0.952387       NaN
# BMIARML        NaN       NaN       NaN       NaN       NaN       NaN
# BMXARMC   0.007320  0.065390  0.966562 -0.007393  0.659909       NaN
# BMIARMC        NaN       NaN       NaN       NaN       NaN       NaN
# BMXWAIST -0.001368  0.101148  0.952469 -0.042764  0.518098       NaN
# BMIWAIST       NaN       NaN       NaN       NaN       NaN       NaN
# BMXSAD1  -0.013054  0.082469  0.899772 -0.158582       NaN       NaN
# BMXSAD2  -0.013609  0.082406  0.900392 -0.170620       NaN       NaN
# BMXSAD3   0.020579  0.031170  0.901288       NaN       NaN       NaN
# BMXSAD4   0.023909  0.033498  0.903409       NaN       NaN       NaN
# BMDAVSAD -0.013367  0.082858  0.900574 -0.164591       NaN       NaN
# BMDSADCM -0.080258 -0.558560 -0.183996       NaN       NaN       NaN
#
#            BMXHEAD  BMIHEAD     BMXHT     BMIHT  ...   BMXARMC  BMIARMC  \
# SEQN     -0.010439      NaN  0.014407 -0.012143  ...  0.007320      NaN
# BMDSTATS -0.062196      NaN -0.038417 -0.503746  ...  0.065390      NaN
# BMXWT     0.872206      NaN  0.786989  0.507097  ...  0.966562      NaN
# BMIWT          NaN      NaN  0.010077  0.480347  ... -0.007393      NaN
# BMXRECUM  0.877795      NaN  0.990304       NaN  ...  0.659909      NaN
# BMIRECUM       NaN      NaN       NaN       NaN  ...       NaN      NaN
# BMXHEAD   1.000000      NaN       NaN       NaN  ...  0.553409      NaN
# BMIHEAD        NaN      NaN       NaN       NaN  ...       NaN      NaN
# BMXHT          NaN      NaN  1.000000       NaN  ...  0.740445      NaN
# BMIHT          NaN      NaN       NaN  1.000000  ...  0.413707      NaN
# BMXBMI         NaN      NaN  0.513398       NaN  ...  0.918190      NaN
# BMDBMIC        NaN      NaN  0.165586       NaN  ...  0.570792      NaN
# BMXLEG         NaN      NaN  0.814782 -0.120391  ...  0.364075      NaN
# BMILEG         NaN      NaN       NaN       NaN  ...       NaN      NaN
# BMXARML   0.569406      NaN  0.961539  0.522637  ...  0.832646      NaN
# BMIARML        NaN      NaN       NaN       NaN  ...       NaN      NaN
# BMXARMC   0.553409      NaN  0.740445  0.413707  ...  1.000000      NaN
# BMIARMC        NaN      NaN       NaN       NaN  ...       NaN      NaN
# BMXWAIST       NaN      NaN  0.693861  0.430256  ...  0.928452      NaN
# BMIWAIST       NaN      NaN       NaN       NaN  ...       NaN      NaN
# BMXSAD1        NaN      NaN  0.407425 -0.004408  ...  0.866448      NaN
# BMXSAD2        NaN      NaN  0.408486  0.004333  ...  0.866936      NaN
# BMXSAD3        NaN      NaN  0.487440       NaN  ...  0.869866      NaN
# BMXSAD4        NaN      NaN  0.486872       NaN  ...  0.871661      NaN
# BMDAVSAD       NaN      NaN  0.408280 -0.000028  ...  0.867210      NaN
# BMDSADCM       NaN      NaN -0.074516  0.041317  ... -0.319636      NaN
#
#           BMXWAIST  BMIWAIST   BMXSAD1   BMXSAD2   BMXSAD3   BMXSAD4  \
# SEQN     -0.001368       NaN -0.013054 -0.013609  0.020579  0.023909
# BMDSTATS  0.101148       NaN  0.082469  0.082406  0.031170  0.033498
# BMXWT     0.952469       NaN  0.899772  0.900392  0.901288  0.903409
# BMIWT    -0.042764       NaN -0.158582 -0.170620       NaN       NaN
# BMXRECUM  0.518098       NaN       NaN       NaN       NaN       NaN
# BMIRECUM       NaN       NaN       NaN       NaN       NaN       NaN
# BMXHEAD        NaN       NaN       NaN       NaN       NaN       NaN
# BMIHEAD        NaN       NaN       NaN       NaN       NaN       NaN
# BMXHT     0.693861       NaN  0.407425  0.408486  0.487440  0.486872
# BMIHT     0.430256       NaN -0.004408  0.004333       NaN       NaN
# BMXBMI    0.937174       NaN  0.919771  0.920123  0.910041  0.912712
# BMDBMIC   0.614724       NaN  0.745925  0.746119  0.777835  0.773577
# BMXLEG    0.235243       NaN  0.208763  0.210433  0.270340  0.271376
# BMILEG         NaN       NaN       NaN       NaN       NaN       NaN
# BMXARML   0.759149       NaN  0.552431  0.553570  0.626635  0.627324
# BMIARML        NaN       NaN       NaN       NaN       NaN       NaN
# BMXARMC   0.928452       NaN  0.866448  0.866936  0.869866  0.871661
# BMIARMC        NaN       NaN       NaN       NaN       NaN       NaN
# BMXWAIST  1.000000       NaN  0.962358  0.962394  0.961273  0.960735
# BMIWAIST       NaN       NaN       NaN       NaN       NaN       NaN
# BMXSAD1   0.962358       NaN  1.000000  0.998425  0.988298  0.988012
# BMXSAD2   0.962394       NaN  0.998425  1.000000  0.994367  0.994266
# BMXSAD3   0.961273       NaN  0.988298  0.994367  1.000000  0.998353
# BMXSAD4   0.960735       NaN  0.988012  0.994266  0.998353  1.000000
# BMDAVSAD  0.962831       NaN  0.999203  0.999533  0.999320  0.999229
# BMDSADCM -0.428438       NaN -0.626736 -0.611939 -0.230849 -0.228721
#
#           BMDAVSAD  BMDSADCM
# SEQN     -0.013367 -0.080258
# BMDSTATS  0.082858 -0.558560
# BMXWT     0.900574 -0.183996
# BMIWT    -0.164591       NaN
# BMXRECUM       NaN       NaN
# BMIRECUM       NaN       NaN
# BMXHEAD        NaN       NaN
# BMIHEAD        NaN       NaN
# BMXHT     0.408280 -0.074516
# BMIHT    -0.000028  0.041317
# BMXBMI    0.920376 -0.201742
# BMDBMIC   0.746645 -0.359864
# BMXLEG    0.210016 -0.026181
# BMILEG         NaN       NaN
# BMXARML   0.553238 -0.191271
# BMIARML        NaN       NaN
# BMXARMC   0.867210 -0.319636
# BMIARMC        NaN       NaN
# BMXWAIST  0.962831 -0.428438
# BMIWAIST       NaN       NaN
# BMXSAD1   0.999203 -0.626736
# BMXSAD2   0.999533 -0.611939
# BMXSAD3   0.999320 -0.230849
# BMXSAD4   0.999229 -0.228721
# BMDAVSAD  1.000000 -0.616438
# BMDSADCM -0.616438  1.000000
#
# [26 rows x 26 columns]

# %%
# %matplotlib inline
import seaborn as sns
sns.heatmap(corr, annot = True)

# %%
import matplotlib.pyplot as plt
dataset.hist(bins=50, figsize=(20, 15))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-31-a05f4cdd1e8e> in <module>()
#       1 import matplotlib.pyplot as plt
# ----> 2 dataset.hist(bins=50, figsize=(20, 15))
#       3 plt.show()
#
# c:\python27\lib\site-packages\pandas\plotting\_core.pyc in hist_frame(data, column, by, grid, xlabelsize, xrot, ylabelsize, yrot, ax, sharex, sharey, figsize, layout, bins, **kwds)
#    2384         >>> hist = df.hist(bins=3)
#    2385     """
# -> 2386     _raise_if_no_mpl()
#    2387     _converter._WARN = False
#    2388     if by is not None:
#
# c:\python27\lib\site-packages\pandas\plotting\_core.pyc in _raise_if_no_mpl()
#      46     # TODO(mpl_converter): remove once converter is explicit
#      47     if not _HAS_MPL:
# ---> 48         raise ImportError("matplotlib is required for plotting.")
#      49
#      50
#
# ImportError: matplotlib is required for plotting.
